# %% [markdown]
# IMPORTING ALL REQUIRED LIBRABRY

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'E:\project\WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# NUMBER OF ROWS AND COLUMNS

# %%
print('Number of rows : ',df.shape[0])
print('Number of columns : ',df.shape[1])
# Out:
# Number of rows :  7043
# Number of columns :  21

# %% [markdown]
# CHECKING FOR NULL VALUES IN DATA

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# VISUALIZATION FOR NULL VALUES BY USING HEAT MAP
#
# Observation:
# -No null values

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# STATISTICAL ANALYSIS OF NUMERICAL FEATURES

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# DATATYPE OF EACH FEATURES

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# CHANGING THE DATATYPE OF TOTAL CHARGES COLUMN FROM OBJECT TYPE TO NUMERIC COLUMN TO PERFORM FURTHER ANALYSIS

# %%
df['Final_Charges']=pd.to_numeric(df['TotalCharges'],errors='coerce').fillna(0).astype(np.float64)

# %%
df['Final_Charges'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# CHANGED DATATYPE OF TOTAL CHARGES FEATURE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# UNIQUES VALUES OF ALL OBJECT TYPE FEATURES BY USING
#
# 1.FOR LOOP AND DICTIONARY
#
# 2.LIST COMPREHENSION

# %%
#1.FOR LOOP AND DICTIONARY
for i in df.select_dtypes(object).columns:
    print({i:df[i].unique()})
# Out:
# {'customerID': array(['7590-VHVEG', '5575-GNVDE', '3668-QPYBK', ..., '4801-JZAZL',
#        '8361-LTMKD', '3186-AJIEK'], dtype=object)}
# {'gender': array(['Female', 'Male'], dtype=object)}
# {'Partner': array(['Yes', 'No'], dtype=object)}
# {'Dependents': array(['No', 'Yes'], dtype=object)}
# {'PhoneService': array(['No', 'Yes'], dtype=object)}
# {'MultipleLines': array(['No phone service', 'No', 'Yes'], dtype=object)}
# {'InternetService': array(['DSL', 'Fiber optic', 'No'], dtype=object)}
# {'OnlineSecurity': array(['No', 'Yes', 'No internet service'], dtype=object)}
# {'OnlineBackup': array(['Yes', 'No', 'No internet service'], dtype=object)}
# {'DeviceProtection': array(['No', 'Yes', 'No internet service'], dtype=object)}
# {'TechSupport': array(['No', 'Yes', 'No internet service'], dtype=object)}
# {'StreamingTV': array(['No', 'Yes', 'No internet service'], dtype=object)}
# {'StreamingMovies': array(['No', 'Yes', 'No internet service'], dtype=object)}
# ...

# %%
#2.LIST COMPREHENSION
df1=[df[i].value_counts()    for i in df.select_dtypes(object).columns]
df1
# Out:
# [7590-VHVEG    1
#  3791-LGQCY    1
#  6008-NAIXK    1
#  5956-YHHRX    1
#  5365-LLFYV    1
#               ..
#  9796-MVYXX    1
#  2637-FKFSY    1
#  1552-AAGRX    1
#  4304-TSPVK    1
#  3186-AJIEK    1
#  Name: customerID, Length: 7043, dtype: int64,
#  Male      3555
#  Female    3488
#  Name: gender, dtype: int64,
#  No     3641
#  Yes    3402
#  Name: Partner, dtype: int64,
#  No     4933
#  Yes    2110
#  Name: Dependents, dtype: int64,
#  Yes    6361
#  No      682
#  Name: PhoneService, dtype: int64,
#  No                  3390
#  Yes                 2971
#  No phone service     682
#  Name: MultipleLines, dtype: int64,
#  Fiber optic    3096
#  DSL            2421
#  No             1526
#  Name: InternetService, dtype: int64,
#  No                     3498
#  Yes                    2019
#  No internet service    1526
#  Name: OnlineSecurity, dtype: int64,
#  No                     3088
#  Yes                    2429
#  No internet service    1526
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'Final_Charges'],
#       dtype='object')

# %% [markdown]
# REPLACING THREE UNIQUE VALUE TO TWO UNIQUE VALUES(YES/NO) IN THESE FEATURES

# %%
df['MultipleLines']=df['MultipleLines'].replace('No phone service','No')
df[['OnlineSecurity', 'OnlineBackup', 'DeviceProtection','TechSupport', 'StreamingTV', 'StreamingMovies']] = df[['OnlineSecurity', 'OnlineBackup', 
                                                                'DeviceProtection', 'TechSupport', 
                                                                'StreamingTV', 'StreamingMovies']].replace('No internet service', 'No')

# %%
print("Unique values of  columns: ")
for i in df.select_dtypes(object).columns:
    print(f'{i}:{df[i].unique()}\n')
# Out:
# Unique values of  columns:
# customerID:['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' ... '4801-JZAZL' '8361-LTMKD'
#  '3186-AJIEK']
#
# gender:['Female' 'Male']
#
# Partner:['Yes' 'No']
#
# Dependents:['No' 'Yes']
#
# PhoneService:['No' 'Yes']
#
# MultipleLines:['No' 'Yes']
#
# InternetService:['DSL' 'Fiber optic' 'No']
#
# OnlineSecurity:['No' 'Yes']
#
# OnlineBackup:['Yes' 'No']
#
# DeviceProtection:['No' 'Yes']
#
# TechSupport:['No' 'Yes']
#
# StreamingTV:['No' 'Yes']
#
# StreamingMovies:['No' 'Yes']
#
# Contract:['Month-to-month' 'One year' 'Two year']
#
# PaperlessBilling:['Yes' 'No']
#
# PaymentMethod:['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
#
# TotalCharges:['29.85' '1889.5' '108.15' ... '346.45' '306.6' '6844.5']
#
# Churn:['No' 'Yes']

# %% [markdown]
# TOP AND MOST FREQUENT VALUES IN ALL THE FEATURES

# %%
df.describe(include=['O']).T.iloc[1:,2:]
# Out:
#                                top  freq
# gender                        Male  3555
# Partner                         No  3641
# Dependents                      No  4933
# PhoneService                   Yes  6361
# MultipleLines                   No  4072
# InternetService        Fiber optic  3096
# OnlineSecurity                  No  5024
# OnlineBackup                    No  4614
# DeviceProtection                No  4621
# TechSupport                     No  4999
# StreamingTV                     No  4336
# StreamingMovies                 No  4311
# Contract            Month-to-month  3875
# PaperlessBilling               Yes  4171
# PaymentMethod     Electronic check  2365
# TotalCharges                          11
# Churn                           No  5174

# %% [markdown]
# VIZUALIZATION OF TARGET FEATURE-CHURN
#
# 1.BAR PLOT
#
# 2.PIE PLOT

# %%
plt.figure(figsize= (10, 7), dpi= 65)
ax=sns.countplot(x='Churn',data=df,palette="rocket")
for i in ax.patches:
    ax.annotate('{:.1f}'.format(i.get_height()),(i.get_x()+0.3, i.get_height()+20))

# %%
plt.figure(figsize=(7,5))
df['Churn'].value_counts().plot(kind='pie',autopct='%.2f%%',explode = [0,0.1])
plt.legend(labels=['No Churn', 'Churn'])
plt.show()

# %%
df.drop('TotalCharges',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'Churn', 'Final_Charges'],
#       dtype='object')

# %% [markdown]
# CORRELATION BETWEEN THE TARGET FEATURE IN RELATION TO OTHER ALL  FEATURES

# %%
df_corr = pd.get_dummies(df[['gender', 'SeniorCitizen', 'Partner', 'Dependents','PhoneService', 'MultipleLines', 
 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'InternetService',
   'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'Churn']]).corr()

# %%
df_corr
# Out:
#                                          SeniorCitizen  gender_Female  \
# SeniorCitizen                                 1.000000       0.001874
# gender_Female                                 0.001874       1.000000
# gender_Male                                  -0.001874      -1.000000
# Partner_No                                   -0.016479      -0.001808
# Partner_Yes                                   0.016479       0.001808
# Dependents_No                                 0.211185       0.010517
# Dependents_Yes                               -0.211185      -0.010517
# PhoneService_No                              -0.008576      -0.006488
# PhoneService_Yes                              0.008576       0.006488
# MultipleLines_No                             -0.142948      -0.008414
# MultipleLines_Yes                             0.142948       0.008414
# OnlineSecurity_No                             0.038653      -0.017021
# ...

# %% [markdown]
# FEATURES POSITIVELY IN RELATION WITH CHURN_YES

# %%
df_corr['Churn_Yes'].sort_values(ascending=False).iloc[1:17]
# Out:
# Contract_Month-to-month           0.405103
# InternetService_Fiber optic       0.308020
# PaymentMethod_Electronic check    0.301919
# PaperlessBilling_Yes              0.191825
# OnlineSecurity_No                 0.171226
# TechSupport_No                    0.164674
# Dependents_No                     0.164221
# SeniorCitizen                     0.150889
# Partner_No                        0.150448
# OnlineBackup_No                   0.082255
# DeviceProtection_No               0.066160
# StreamingTV_Yes                   0.063228
# StreamingMovies_Yes               0.061382
# MultipleLines_Yes                 0.040102
# PhoneService_Yes                  0.011942
# gender_Female                     0.008612
# Name: Churn_Yes, dtype: float64

# %% [markdown]
# VIZUALIZATION OF CORRELATED VALUES

# %%
plt.figure(figsize=(10,5),dpi=150)
sns.barplot(x= df_corr['Churn_Yes'].sort_values(ascending=False).iloc[1:-1].index, y=df_corr['Churn_Yes'].sort_values(ascending=False).iloc[1:-1].values,palette='rocket')
plt.xticks(rotation= 90)
plt.title('feature correlation with churn_yes')
plt.show()

# %% [markdown]
# DEMOGRAPIC FEATURE-
#
# 1.Gender
#
# 2.SeniorCitizen
#
# 3.Partner
#
# 4.Dependents

# %% [markdown]
# COMPARING THE CHURN VALUE AND GENDER

# %%
ax=sns.countplot(x='gender',hue='Churn',data=df,palette='rocket') 


for i in ax.patches:
    ax.annotate('{:.1f}'.format(i.get_height()),(i.get_x()+0.05, i.get_height()+20))

table = pd.DataFrame(round(df.groupby('gender')['Churn'].value_counts(normalize = True),2))
table = plt.table(cellText=table.values,
          rowLabels=table.index,
          colLabels=table.columns,
          bbox=(1.5, 0,0.4 , 0.45))
table.auto_set_font_size(False)
table.set_fontsize(12)
plt.show()

# %%
df["Churn"]= df["Churn"].map({"No" : 0 , "Yes": 1})

# %%
sns.set_theme(style ='darkgrid')
g=sns.PairGrid(df, y_vars = 'Churn',
             x_vars = ['gender'], height = 6, aspect =0.80)
g.map(sns.pointplot, scale = 2, errwidth =1, color = 'black')

# %% [markdown]
# OBSERVATION:
#
# -gender column doesnot effect the churn
#
# because the frequency of male and female on churn_yes is almost same

# %% [markdown]
#  COMPARING THE CHURN VALUE AND SENIOR CITIZEN

# %%
df["SeniorCitizen"]= df["SeniorCitizen"].map({0: "young_adult", 1: "Senior_old"})
ax=sns.countplot(x='SeniorCitizen',hue='Churn',data=df,palette='rocket') 


for i in ax.patches:
    ax.annotate('{:.1f}'.format(i.get_height()),(i.get_x()+0.05, i.get_height()+20))

table = pd.DataFrame(round(df.groupby('SeniorCitizen')['Churn'].value_counts(normalize = True),2))
table = plt.table(cellText=table.values,
          rowLabels=table.index,
          colLabels=table.columns,
          bbox=(1.5, 0,0.4 , 0.45))
table.auto_set_font_size(False)
table.set_fontsize(12)
plt.show()

# %%
sns.set_theme(style ='darkgrid')
g=sns.PairGrid(df, y_vars = 'Churn',
             x_vars = ['SeniorCitizen'], height = 6, aspect =0.80)
g.map(sns.pointplot, scale = 2, errwidth =1, color = 'black')
g.map_offdiag(sns.barplot)

# %%
plt.figure(figsize=(6,5))
ax = sns.histplot(data=df, x ='SeniorCitizen',hue = 'Churn',legend=True,palette=['green', 'black'])
ax.tick_params(axis='x')
plt.title('Senior Citizens vs Churn')
plt.show()

# %% [markdown]
# observation:
#
# -senior citizens are likely to churn more compared to young and adult people

# %% [markdown]
# PARTNERS AND CHURN RELATION

# %%
df["Partner"]=df["Partner"].map({'No': "Have_partner", 'Yes': "No_partner"})

# %%
ax=sns.countplot(x='Partner',hue='Churn',data=df,palette='rocket') 

for i in ax.patches:
    ax.annotate('{:.1f}'.format(i.get_height()),(i.get_x()+0.05, i.get_height()+20))

table = pd.DataFrame(round(df.groupby('Partner')['Churn'].value_counts(normalize = True),2))
table = plt.table(cellText=table.values,
          rowLabels=table.index,
          colLabels=table.columns,
          bbox=(1.5, 0,0.4 , 0.45))
table.auto_set_font_size(False)
table.set_fontsize(12)
plt.show()

# %%
plt.figure(figsize=(4,4))
ax = sns.histplot(data=df, x ='Partner',hue = 'Churn',legend=True,palette=['black', 'red'])
ax.tick_params(axis='x')
plt.title('Partner vs Churn')
plt.show()

# %% [markdown]
# observation:
#
# -if the customer have partner ,likely to have more churn

# %% [markdown]
# DEPENDENT AND CHURN RELATION

# %%
df["Dependents"]=df["Dependents"].map({'No': "Indenpendent", 'Yes': "dependent"})

# %%
ax=sns.countplot(x='Dependents',hue='Churn',data=df,palette='rocket') 


for i in ax.patches:
    ax.annotate('{:.1f}'.format(i.get_height()),(i.get_x()+0.05, i.get_height()+20))

table = pd.DataFrame(round(df.groupby('Dependents')['Churn'].value_counts(normalize = True),2))
table = plt.table(cellText=table.values,
          rowLabels=table.index,
          colLabels=table.columns,
          bbox=(1.5, 0,0.4 , 0.45))
table.auto_set_font_size(False)
table.set_fontsize(12)
plt.show()

# %% [markdown]
# observation:
#
# -customers who are independent are likely  more churn the company

# %%
df['Churn_rate']=df['Churn'].map({'No':0,'Yes':1})

# %%
df['Churn_rate'].mean()
# Out:
# 0.2653698707936959

# %% [markdown]
# STASTICAL ANALYSIS

# %% [markdown]
# Numerical variables

# %%
plt.figure(figsize=(4,6))
ax = sns.histplot(data=df, x ='tenure',hue = 'Churn',legend=True,palette=['red', 'cyan'])
ax.tick_params(axis='x', rotation=45)
plt.title('Tenure Negative Effect on Churn')
plt.show()

# %% [markdown]
# -Most customers churn within the first year of subscription, while customers with longer tenures are not as likely to churn.
#
# -Looking at the plots, it appears that those with more tenure are less likely to churn.
#
# -This result is intuitive as people who have been with the company for longer are less likely to switch companies.

# %%
plt.figure(figsize=(4,6))
ax = sns.histplot(data=df, x ='PhoneService',hue = 'Churn',legend=True,palette=['red', 'cyan'])
ax.tick_params(axis='x', rotation=45)
plt.title('PhoneService vs Churn')
plt.show()

# %% [markdown]
# -If there is phoneservice people are less likely to churn

# %%
plt.figure(figsize=(4,6))
ax = sns.countplot(data=df, x ='MultipleLines',hue = 'Churn',palette=['cyan','blue'])
ax.tick_params(axis='x')
plt.title('MultipleLines vs Churn')
plt.show()

# %%
plt.figure(figsize=(4,6))
ax = sns.histplot(data=df, x ='InternetService',hue = 'Churn',legend=True,palette=['cyan','red'])
ax.tick_params(axis='x', rotation=45)
plt.title('InternetService vs Churn')
plt.show()

# %%
plt.figure(figsize=(4,6))
ax = sns.histplot(data=df, x ='OnlineBackup',hue = 'Churn',legend=True,palette=['green','blue'])
ax.tick_params(axis='x', rotation=45)
plt.title('OnlineBackup effect on Churn')
plt.show()

# %%
plt.figure(figsize=(4,6))
ax = sns.histplot(data=df, x ='DeviceProtection',hue = 'Churn',legend=True,palette=['green','blue'])
ax.tick_params(axis='x', rotation=45)
plt.title('DeviceProtection effect on Churn')
plt.show()

# %%
plt.figure(figsize=(4,6))
ax = sns.countplot(data=df, x ='DeviceProtection',hue = 'Churn',palette=['green','blue'])
ax.tick_params(axis='x', rotation=45)
plt.title('')
plt.show()

# %%
sns.histplot(data = df,x= "Churn",hue = 'Contract',multiple='stack')
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='Count'>

# %% [markdown]
# -It clear from above monthly contract has more churn
#
# -This may be due to a possible penalty incurred for those who break the contract and may be worth looking more into for insight.

# %%
df[df['TotalCharges'] == " "]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
df['TotalCharges'].replace(" ", '0', inplace=True)
df.TotalCharges.astype("float64")
df['TotalCharges'] = df['TotalCharges'].astype(float)

# %%
sns.boxplot(data=df, x="TotalCharges", y="Churn")
plt.show()
sns.histplot(data = df,x= "TotalCharges",hue = 'Churn',multiple='stack')
plt.show()

# %%
sns.set(rc={'figure.figsize':(5,5)})

fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)

sns.boxplot(data=df, y="tenure", x="PaperlessBilling")
plt.show()
sns.boxplot(data=df, y="tenure", x= "Contract")
plt.show()
sns.scatterplot(data=df, x="tenure", y="MonthlyCharges", hue="Churn")
plt.show()
sns.scatterplot(data=df, x="tenure", y="TotalCharges", hue="Churn")
plt.show()

# %% [markdown]
# -Looking at the plots, tenure appears to have no significant correlation with Paperless Billing or MonthlyCharges.
#
# -However, tenure does appear to have a notable correlation with both contract and TotalCharges.
#
# -We expected tenure and TotalCharges to be correlated since more charges accumulate throughout a tenure. I was not expecting a relationship between contract and tenure. In hindsight, it makes sense that people with longer tenures would opt for longer contracts which are probably cheaper.
#
# -If this is true, we'll see a relationship between contract and MonthlyCharge as well.

# %%
sns.set(rc={'figure.figsize':(10,12)})

fig = plt.figure()
fig.subplots_adjust(hspace=0.2, wspace=0.2)
ax = fig.add_subplot(2, 2, 1)
sns.histplot(data = df,x= "PaperlessBilling",hue = 'Contract',multiple='stack')
ax = fig.add_subplot(2, 2, 2)
sns.boxplot(data=df, y="MonthlyCharges", x="PaperlessBilling")
ax = fig.add_subplot(2, 2, 3)
sns.boxplot(data=df, y="TotalCharges", x="PaperlessBilling")
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

plt.show()

# %% [markdown]
# -Paperless Billing appear have slightly larger ratio of month-to-month contracts compared to no Paperless Billing.
#
# - paperless Billing appear to have a higher average Monthly Charge.

# %% [markdown]
# -tenure appears highly correlated with churn

# %% [markdown]
# Numerical insight

# %%
df['SeniorCitizen'] = df['SeniorCitizen'].apply(lambda x: "Senior" if x==1 else ("Non-Senior" if x==0 else x))

cols = ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 
        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 
        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 
        'Contract', 'PaperlessBilling', 'PaymentMethod']

fig, ax = plt.subplots(4,4,figsize=(18,8), sharex=True)

j=0
k=0
    
for i in cols:
    temp = df.pivot_table(df, index=[i], columns=['Churn'], aggfunc=len).reset_index()[[i,'tenure']]
    temp.columns=[i,'Churn_N','Churn_Y']
    temp['Churn_ratio']=(temp['Churn_Y'])/(temp['Churn_Y']+temp['Churn_N'])
    
    a = sns.barplot(x='Churn_ratio', y=i, data=temp, ax=ax[j][k], color="palegreen")
    a.set_yticklabels(labels=temp[i])
    for p in ax[j][k].patches:
        ax[j][k].text(p.get_width() + .05, p.get_y() + p.get_height()/1.5, '{:,.1%}'.format(p.get_width()),
                   fontsize=8, color='black', ha='center', va='bottom')
    ax[j][k].set_xlabel('', size=8, color="green")
    ax[j][k].set_ylabel('', size=8, color="green", rotation=0, horizontalalignment='right')
    ax[j][k].set_title(i, size=10, color="green")
    #print(j,k)
    if k==3: 
        j=j+1
        k=0
    else:
        k=k+1 
    
fig.suptitle("Churn ratio across attributes", fontsize=14, family='sans-serif', color="green")
plt.subplots_adjust(left=None, bottom=None, right=None, top=None,
                    wspace=1, hspace=1)
plt.xlim(0,.5)
plt.show()

# %% [markdown]
# Tenure insight

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,6), sharey=True, sharex=True)

sns.distplot(df[df['Churn']=="Yes"]["tenure"] , color="#F5B7B1", ax=ax[0])
sns.distplot(df[df['Churn']=="No"]["tenure"] , color="#ABEBC6", ax=ax[1])
        
ax[0].set_xlabel('Churn - Yes', size=12, color="#800000")
ax[1].set_xlabel('Churn - No', size=12, color="green")
fig.suptitle("Tenure distribution", fontsize=14)
plt.show()
# Out:
# C:\Users\Mahamad Azar K\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Mahamad Azar K\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Monthly charges

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,6), sharey=True, sharex=True)

sns.distplot(df[df['Churn']=="Yes"]["MonthlyCharges"] , color="#F5B7B1", ax=ax[0])
sns.distplot(df[df['Churn']=="No"]["MonthlyCharges"] , color="#ABEBC6", ax=ax[1])
        
ax[0].set_xlabel('Churn - Yes', size=12, color="#800000")
ax[1].set_xlabel('Churn - No', size=12, color="green")

fig.suptitle("Monthly Charges distribution", fontsize=14)
plt.show()
# Out:
# C:\Users\Mahamad Azar K\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Mahamad Azar K\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 45% of the users paying via electronic check churn
#
# 43% of the users under month-to-month contract churn
#
# 42% of the users with fiber optic internet churn
#
# 42% of the users no online security churn
#
# 42% of the users opting no for TechSupport churn
#
# 42% of the senior citizen users churn
#
# 40% of the users with no OnlineBackup churn
#
# 39% of the users with no DeviceProtection churn
#
# More the tenure is, lesser is the churn ratio
#
# Higher the monthly charge is, higher the churn
#
# Churned data points are concentrated in high monthly charges and low tenure.
#
# Not churned data points are concentrated in (1) low monthly charges & low tenure and (2) high monthly charges & high tenure.
